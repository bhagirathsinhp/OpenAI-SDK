# %%
from dotenv import load_dotenv 
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt=40-mini")
