# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict

# %%
load_dotenv(override=True) 
from_email = os.getenv("FROM_EMAIL")
to_email = os.getenv("TO_EMAIL")

# %%
#Test for sending email:
# def send_test_email():
#     sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
#     from_email = Email("rengokukoh@gmail.com")  
#     to_email = To("123shivaay@gmail.com") 
#     content = Content("text/plain", "This is an important test email")
#     mail = Mail(from_email, to_email, "Test email", content).get()
#     response = sg.client.mail.send.post(request_body=mail)
#     print(response.status_code)

# send_test_email()

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
# sales_agent1 = Agent(
#   name="Professional Sales Agent",
#   instructions=instructions1,
#   model="gpt-4o-mini",
# )

# sales_agent2 = Agent(
#   name="Humorous Sales Agent",
#   instructions=instructions2,
#   model="gpt-4o-mini",
# )

# sales_agent3 = Agent(
#   name="Busy Sales Agent",
#   instructions=instructions3,
#   model="gpt-4o-mini",
# )

# %%
# result = Runner.run_streamed(sales_agent1, input="Write a cold sales email.")
# async for event in result.stream_events():
#     if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
#         print(event.data.delta, end="", flush=True)
# Out:
# Subject: Simplify Your SOC 2 Compliance with AI-Powered Solutions
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. My name is [Your Name], and I am with ComplAI, where we specialize in helping organizations streamline their SOC 2 compliance efforts.
#
# Navigating the complexities of SOC 2 compliance can be time-consuming and resource-intensive. Our AI-powered SaaS tool simplifies this process, enabling you to effortlessly prepare for audits while providing ongoing compliance management.
#
# Here are a few ways ComplAI can support your organization:
#
# - **Automated Documentation**: Reduce manual paperwork and ensure you have the right documentation ready for your auditors.
# - **Real-Time Monitoring**: Keep track of compliance metrics and identify potential issues before they escalate.
# - **Tailored Compliance Roadmap**: Receive a customized action plan to meet your specific industry needs and regulatory requirements.
#
# I would love the opportunity to discuss how ComplAI can help you enhance your compliance workflows. Are you available for a brief call this week?
#
# Thank you for your time, and I look forward to connecting.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your Email Address]
# [Company Website]

# %%
# message = "Write a cold sales email."

# with trace("Parallel cold emails"):
#   results = await asyncio.gather(
#     Runner.run(sales_agent1, input=message),
#     Runner.run(sales_agent2, input=message),
#     Runner.run(sales_agent3, input=message),  
#   )
  
#   outputs = [result.final_output for result in results]
  
#   for output in outputs:
#     print("\n\n---\n\n")
#     print(output)
# Out:
# ---
#
#
# Subject: Streamline Your SOC 2 Compliance with ComplAI
#
# Dear [Recipient's Name],
#
# I hope this message finds you well. My name is [Your Name], and I am reaching out to introduce you to ComplAI, a cutting-edge SaaS solution designed to simplify the SOC 2 compliance process.
#
# As organizations increasingly prioritize data security and regulatory compliance, navigating the complexities of SOC 2 requirements can be daunting. ComplAI leverages AI technology to streamline compliance workflows, ensuring that your team remains efficient and focused on what truly matters—your business.
#
# Key benefits of using ComplAI include:
#
# - **Automated Documentation**: Reduce manual efforts by generating compliant documentation tailored to your organization’s needs.
# - **Real-time Monitoring**: Track compliance progress with our intuitive dashboard, providing insights and alerts to keep you on track.
# - **Auditor Ready**: Be prepared for audits with ease, presenting organized and easily accessible documentation to auditors.
#
# I believe that ComplAI can significantly enhance your compliance strategy, saving you valuable time and resources. Would you be open to a brief call next week to discuss how we can assist your team in achieving and maintaining SOC 2 compliance?
#
# Thank you for considering this opportunity. I look forward to the possibility of connecting.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your Email Address]
# [Your LinkedIn Profile (if applicable)]
#
#
# ---
#
#
# Subject: Don’t Let SOC 2 Compliance Give You Sleepless Nights! 😴
#
# Hi [Recipient's Name],
#
# I hope you’re having a better day than my coffee pot— it just broke! If only I had a compliance tool that could brew up the perfect audit preparation...
#
# Speaking of brewing up improvements, I wanted to introduce you to ComplAI! Think of us as your loyal sidekick in the wild and wacky world of SOC 2 compliance. Our AI-powered SaaS tool takes the headache out of preparing for audits, so you can focus on what really matters—like figuring out how to duplicate the best cup of coffee. ☕️
#
# With ComplAI, you’ll:
# - **Sleep Like a Baby:** Our intuitive dashboard guides you step by step through compliance.
# - **Avoid Audit Anxiety:** Get proactive alerts and recommendations that make audits feel like a gentle stroll rather than a marathon.
# - **Impress Your Stakeholders:** Show them you’ve got compliance handled—just like I should’ve handled that coffee pot!
#
# Want to see how we can transform your SOC 2 journey from chaos to zen? Let’s chat! I promise it’ll be more exciting than scrolling through TikTok during your lunch break.
#
# Looking forward to hearing from you!
#
# Best,
#
# [Your Name]
# Compliance Enthusiast & Coffee Lover
# ComplAI
# [Your Phone Number]
# [Your LinkedIn Profile] (if applicable)
#
#
# ---
#
#
# Subject: Simplify Your SOC 2 Compliance Process
#
# Hi [Recipient's Name],
#
# I hope this email finds you well. I’m reaching out because I believe ComplAI can help streamline your SOC 2 compliance and audit preparations.
#
# Our AI-powered tool automates tedious tasks and provides real-time insights, making the entire process more efficient and less stressful. Companies like [Client Name] have already seen significant time savings and reduced audit costs.
#
# Would you be open to a quick call to see how we can help your team?
#
# Best,
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your Website]

# %%
# sales_picker = Agent(
#     name="sales_picker",
#     instructions="You pick the best cold sales email from the given options. \
# Imagine you are a customer and pick the one you are most likely to respond to. \
# Do not give an explanation; reply with the selected email only.",
#     model="gpt-4o-mini"
# )

# %%
# message = "Write a cold sales email."

# with trace("Selection from sales people"):
#   results = await asyncio.gather(
#     Runner.run(sales_agent1, input=message),
#     Runner.run(sales_agent2, input=message),
#     Runner.run(sales_agent3, input=message),  
#   )
  
#   outputs = [result.final_output for result in results]
  
#   emails = "Cold Sales emails:\n\n" + "\n\n---\n\n".join(outputs)
  
#   best = await Runner.run(sales_picker, input=emails)
#   print(f"Best sales email:\n\n{best.final_output}")
# Out:
# Best sales email:
#
# Subject: Is Your SOC2 Compliance Playing Hide and Seek? 🤔
#
# Hey [Recipient's Name],
#
# I hope this email finds you in the middle of a well-deserved coffee break (or perhaps searching for the last piece of compliance magic you can't quite find)!
#
# At ComplAI, we know that navigating SOC2 compliance can sometimes feel like a never-ending quest, akin to finding the last cookie in a jar—frustrating and a little bit messy. But worry not! Our AI-powered tool is here to turn that ‘where on Earth is it?’ into ‘found it!’ just like your favorite snack! 🍪
#
# Imagine having a trusty sidekick that not only streamlines your compliance process but also prepares you for audits faster than you can say “What’s the point of all this paperwork?” 🥳 With ComplAI, you can focus on what you do best—like perfecting your karaoke skills or mastering the art of office snack-hoarding.
#
# Want to see how we can make compliance not just easier, but a whole lot more fun? Let’s schedule a quick chat! I promise I won’t ask you to sing a duet… this time. 😉
#
# Looking forward to potentially helping you ace that audit!
#
# Best,
# [Your Name]
# Your Compliance Cheerleader at ComplAI
# [Your Phone Number]
# [Your LinkedIn Profile]
#
# P.S. Did I mention our tool can save you time and headaches? Because who doesn’t love more time for those office breaks? 🕒

# %%
sales_agent1 = Agent(
  name="Professional Sales Agent",
  instructions=instructions1,
  model="gpt-4o-mini",
)

sales_agent2 = Agent(
  name="Humorous Sales Agent",
  instructions=instructions2,
  model="gpt-4o-mini",
)

sales_agent3 = Agent(
  name="Busy Sales Agent",
  instructions=instructions3,
  model="gpt-4o-mini",
)

# %%
@function_tool
def send_email(body: str):
    """Send out an email with the given body to all sales prospects."""
    # The modern SendGrid Mail object accepts strings directly, 
    # completely removing the need for Email(), To(), and Content() objects.
    message = Mail(
        from_email="rengokukoh@gmail.com",
        to_emails="123shivaay@gmail.com",
        subject="Sales email",
        plain_text_content=body
    )
    
    try:
        sg = sendgrid.SendGridAPIClient(api_key=os.environ.get("SENDGRID_API_KEY"))
        # sg.send() directly accepts the Mail object in modern versions
        response = sg.send(message)
        return {"status": "success", "status_code": response.status_code}
    except Exception as e:
        return {"status": "error", "error_message": str(e)}

# %%
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects.', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x00000143AC445EE0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email.")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email.', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x00000143AD6BD3A0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %%
description = "Write a cold sales email."
agents = [sales_agent1, sales_agent2, sales_agent3]

tools = [agent.as_tool(tool_name=f'sales_agent{i}', tool_description=description) for i, agent in enumerate(agents, start=1)] + [send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email.', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x00000143A8B98C20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email.', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x00000143A968FD80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent3', description='Write a cold sales email.', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x00000143A96E3600>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects.', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x00000143AC445EE0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %%
instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gpt-4o-mini")

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message)

# %%
print(results)
# Out:
# [RunResult(input='Write a cold sales email.', new_items=[MessageOutputItem(agent=Agent(name='Professional Sales Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_0e5017c13de0d0430069ccfc6efe688190951d1eb1a9754ca1', content=[ResponseOutputText(annotations=[], text="Subject: Streamline Your SOC 2 Compliance with AI-Driven Solutions\n\nDear [Recipient's Name],\n\nI hope this message finds you well.\n\nAs organizations increasingly prioritize data security, ensuring SOC 2 compliance has become a critical requirement for maintaining trust with clients and stakeholders. I’m reaching out to introduce you to ComplAI, an innovative SaaS solution designed to simplify and automate the compliance process.\n\nOur AI-powered platform not only streamlines the preparation for SOC 2 audits but also ensures that your organization maintains ongoing compliance with ease. Here are a few key benefits of our tool:\n\n- **Automated Documentation**: Reduce manual effort with real-time updates and templates tailored to your specific needs.\n- **Risk Assessment**: Identify vulnerabilities and mitigate risks proactively, saving you time and resources during audits.\n- **Continuous Monitoring**: Stay compliant year-round with automated checks and balances.\n\nCompanies using ComplAI have reported significant improvements in audit readiness and reduced compliance costs. I’d love to schedule a brief call to discuss how we can help your organization achieve and maintain SOC 2 compliance efficiently.\n\nPlease let me know your availability for a conversation.\n\nThank you for your time, and I look forward to the opportunity to connect.\n\nBest regards,\n\n[Your Name]  \n[Your Position]  \nComplAI  \n[Your Phone Number]  \n[Your Email Address]  \n[Website URL]  ", type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None), type='message_output_item')], raw_responses=[ModelResponse(output=[ResponseOutputMessage(id='msg_0e5017c13de0d0430069ccfc6efe688190951d1eb1a9754ca1', content=[ResponseOutputText(annotations=[], text="Subject: Streamline Your SOC 2 Compliance with AI-Driven Solutions\n\nDear [Recipient's Name],\n\nI hope this message finds you well.\n\nAs organizations increasingly prioritize data security, ensuring SOC 2 compliance has become a critical requirement for maintaining trust with clients and stakeholders. I’m reaching out to introduce you to ComplAI, an innovative SaaS solution designed to simplify and automate the compliance process.\n\nOur AI-powered platform not only streamlines the preparation for SOC 2 audits but also ensures that your organization maintains ongoing compliance with ease. Here are a few key benefits of our tool:\n\n- **Automated Documentation**: Reduce manual effort with real-time updates and templates tailored to your specific needs.\n- **Risk Assessment**: Identify vulnerabilities and mitigate risks proactively, saving you time and resources during audits.\n- **Continuous Monitoring**: Stay compliant year-round with automated checks and balances.\n\nCompanies using ComplAI have reported significant improvements in audit readiness and reduced compliance costs. I’d lov ...
